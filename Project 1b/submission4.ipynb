# %%
from sklearn.metrics import mean_squared_error
import pandas as pd
from sklearn.linear_model import RidgeCV, LassoCV, LinearRegression
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import RidgeCV

# %%
trainset = pd.read_csv('train.csv')
X = trainset.drop(trainset.columns[[0,1]],axis=1)
y = pd.DataFrame(trainset['y'])

# %%
#feature transformation
#quadratic x6-x10
X_squared = X**2
X_squared.columns=['x6', 'x7','x8', 'x9', 'x10']
X_trafo = pd.concat([X, X_squared],axis=1)

#exponential x11-x15
X_exp = np.exp(X)
X_exp.columns=['x11', 'x12','x13', 'x14', 'x15']
X_trafo = pd.concat([X_trafo, X_exp],axis=1)

#cosine x16-x20
X_cos = np.cos(X)
X_cos.columns=['x16', 'x17','x18', 'x19', 'x20']
X_trafo = pd.concat([X_trafo, X_cos],axis=1)

#constant x21
X_trafo['x21'] = np.ones_like(700)

X_train, X_test, y_train, y_test = train_test_split(
    X_trafo, y, test_size=0.05, random_state=0)

display(X_trafo)
# Out:
#        x1    x2    x3    x4    x5      x6      x7      x8      x9     x10  \
# 0    0.02  0.05 -0.09 -0.43 -0.08  0.0004  0.0025  0.0081  0.1849  0.0064
# 1   -0.13  0.11 -0.08 -0.29 -0.03  0.0169  0.0121  0.0064  0.0841  0.0009
# 2    0.08  0.06 -0.07 -0.41 -0.03  0.0064  0.0036  0.0049  0.1681  0.0009
# 3    0.02 -0.12  0.01 -0.43 -0.02  0.0004  0.0144  0.0001  0.1849  0.0004
# 4   -0.14 -0.12 -0.08 -0.02 -0.08  0.0196  0.0144  0.0064  0.0004  0.0064
# ..    ...   ...   ...   ...   ...     ...     ...     ...     ...     ...
# 695  0.31 -0.09  0.04 -0.09  0.03  0.0961  0.0081  0.0016  0.0081  0.0009
# 696 -0.26 -0.01  0.02 -0.40  0.05  0.0676  0.0001  0.0004  0.1600  0.0025
# 697 -0.27 -0.22 -0.01 -0.32 -0.05  0.0729  0.0484  0.0001  0.1024  0.0025
# 698  0.19  0.11 -0.05 -0.27 -0.04  0.0361  0.0121  0.0025  0.0729  0.0016
# 699 -0.09 -0.09 -0.06 -0.41 -0.06  0.0081  0.0081  0.0036  0.1681  0.0036
#
#      ...       x12       x13       x14       x15       x16       x17  \
# 0    ...  1.051271  0.913931  0.650509  0.923116  0.999800  0.998750
# 1    ...  1.116278  0.923116  0.748264  0.970446  0.991562  0.993956
# 2    ...  1.061837  0.932394  0.663650  0.970446  0.996802  0.998201
# 3    ...  0.886920  1.010050  0.650509  0.980199  0.999800  0.992809
# 4    ...  0.886920  0.923116  0.980199  0.923116  0.990216  0.992809
# ..   ...       ...       ...       ...       ...       ...       ...
# 695  ...  0.913931  1.040811  0.913931  1.030455  0.952334  0.995953
# 696  ...  0.990050  1.020201  0.670320  1.051271  0.966390  0.999950
# 697  ...  0.802519  0.990050  0.726149  0.951229  0.963771  0.975897
# 698  ...  1.116278  0.951229  0.763379  0.960789  0.982004  0.993956
# 699  ...  0.913931  0.941765  0.663650  0.941765  0.995953  0.995953
#
#           x18       x19       x20  x21
# 0    0.995953  0.908966  0.996802    1
# 1    0.996802  0.958244  0.999550    1
# 2    0.997551  0.917121  0.999550    1
# 3    0.999950  0.908966  0.999800    1
# 4    0.996802  0.999800  0.996802    1
# ..        ...       ...       ...  ...
# 695  0.999200  0.995953  0.999550    1
# 696  0.999800  0.921061  0.998750    1
# 697  0.999950  0.949235  0.998750    1
# 698  0.998750  0.963771  0.999200    1
# 699  0.998201  0.917121  0.998201    1
#
# [700 rows x 21 columns]

# %%
import statsmodels.formula.api as smf
from statsmodels.iolib.summary2 import summary_col

res = smf.ols("y ~ x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8 + x9 + x10 + x11 + x12 + x13 + x14 + x15 + x16 + x17 + x18 + x19 + x20 + x21", data=X_trafo).fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.036
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     1.255
# Date:                Wed, 23 Mar 2022   Prob (F-statistic):              0.203
# Time:                        09:08:14   Log-Likelihood:                -1454.3
# No. Observations:                 700   AIC:                             2951.
# Df Residuals:                     679   BIC:                             3046.
# Df Model:                          20
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -3344.5948   6144.739     -0.544      0.586   -1.54e+04    8720.378
# x1            87.1989     90.710      0.961      0.337     -90.907     265.304
# x2           -67.2701    114.965     -0.585      0.559    -293.000     158.459
# x3            28.5382    669.724      0.043      0.966   -1286.441    1343.518
# x4           158.0755     93.568      1.689      0.092     -25.642     341.793
# x5          -819.6964   1563.935     -0.524      0.600   -3890.427    2251.034
# x6           200.0496    719.442      0.278      0.781   -1212.549    1612.648
# x7          -393.5418    944.999     -0.416      0.677   -2249.014    1461.930
# x8          1953.2622   3789.483      0.515      0.606   -5487.251    9393.776
# x9          -523.6329    368.121     -1.422      0.155   -1246.425     199.160
# x10         1518.9342   2384.618      0.637      0.524   -3163.177    6201.045
# x11          -86.6057     89.748     -0.965      0.335    -262.823      89.612
# x12           65.3403    113.995      0.573      0.567    -158.485     289.166
# x13          -30.9921    668.082     -0.046      0.963   -1342.748    1280.763
# x14         -155.7717     92.258     -1.688      0.092    -336.918      25.375
# x15          822.1081   1566.669      0.525      0.600   -2253.990    3898.206
# x16          327.1100   1481.040      0.221      0.825   -2580.859    3235.079
# x17         -737.6402   1945.318     -0.379      0.705   -4557.203    3081.922
# x18         3890.6703   8149.418      0.477      0.633   -1.21e+04    1.99e+04
# x19        -1211.2283    813.537     -1.489      0.137   -2808.578     386.121
# x20         3799.8218   6187.105      0.614      0.539   -8348.336    1.59e+04
# x21        -3344.5948   6144.739     -0.544      0.586   -1.54e+04    8720.378
# ==============================================================================
# Omnibus:                        3.275   Durbin-Watson:                   2.066
# Prob(Omnibus):                  0.195   Jarque-Bera (JB):                3.115
# Skew:                           0.133   Prob(JB):                        0.211
# Kurtosis:                       3.190   Cond. No.                     1.63e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.93e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
display(mean_squared_error(y_test,y_pred)**0.5)
display(ridge.coef_)

pd.DataFrame(reg.coef_).to_csv('submission.csv', index=False, header=False)
